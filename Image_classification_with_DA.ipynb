# %% [markdown]
# # Develop cat dog image classification using CNN

# %% [markdown]
# # Steps
# 1. Load your data
# 2. Data proper structure
# 3. Loading training data and test data from directory
# 4. Create CNN model.
# 5. Compile, run, evaluate the model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                    rotation_range=40,
                                    width_shift_range=40,
                                    height_shift_range=0.2,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest')
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/CNN_FILES_DS_US/training_set.zip")
zip_ref.extractall('/content')
zip_ref.close()

# %%
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/CNN_FILES_DS_US/test_set.zip")
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# Create training and test dataset

# %%
training_set = train_datagen.flow_from_directory(
    directory = '/content/training_set',
    batch_size = 32,
    target_size = (64, 64),
    class_mode='binary'
)
# Out:
# Found 8005 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
    directory = '/content/test_set',
    batch_size = 32,
    target_size = (64, 64),
    class_mode='binary'
 )
# Out:
# Found 2023 images belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout

# %% [markdown]
# Create CNN Architecture

# %%
# create CNN model

model=Sequential()
# CNN
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(64,64,3))) # feature extraction, kernel shape
#pooling
model.add(MaxPooling2D(pool_size=(2,2))) # reduce the dimention
# 2 Conv layer
model.add(Conv2D(32,(3,3),activation='relu'))
#pooling
model.add(MaxPooling2D(pool_size=(2,2)))

#FCN
model.add(Flatten()) # ANN will always take data in one Dim
model.add(Dense(128,activation='relu'))
model.add(Dense(1,activation='sigmoid')) # binary classification model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 31, 31, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_2 (Dense)             (None, 128)               802944
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 813217 (3.10 MB)
# Trainable params: 813217 (3.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(training_set, validation_data=test_set, epochs=10)
# Out:
# Epoch 1/10
# 251/251 [==============================] - 25s 92ms/step - loss: 0.6844 - accuracy: 0.5548 - val_loss: 0.6572 - val_accuracy: 0.5897
# Epoch 2/10
# 251/251 [==============================] - 25s 101ms/step - loss: 0.6757 - accuracy: 0.5775 - val_loss: 0.6484 - val_accuracy: 0.6268
# Epoch 3/10
# 251/251 [==============================] - 24s 94ms/step - loss: 0.6541 - accuracy: 0.6080 - val_loss: 0.6284 - val_accuracy: 0.6352
# Epoch 4/10
# 251/251 [==============================] - 23s 92ms/step - loss: 0.6497 - accuracy: 0.6071 - val_loss: 0.6295 - val_accuracy: 0.6431
# Epoch 5/10
# 251/251 [==============================] - 24s 96ms/step - loss: 0.6369 - accuracy: 0.6287 - val_loss: 0.6044 - val_accuracy: 0.6688
# Epoch 6/10
# 251/251 [==============================] - 24s 94ms/step - loss: 0.6284 - accuracy: 0.6372 - val_loss: 0.6263 - val_accuracy: 0.6367
# Epoch 7/10
# 251/251 [==============================] - 22s 89ms/step - loss: 0.6250 - accuracy: 0.6452 - val_loss: 0.6491 - val_accuracy: 0.6189
# Epoch 8/10
# 251/251 [==============================] - 24s 96ms/step - loss: 0.6196 - accuracy: 0.6556 - val_loss: 0.5752 - val_accuracy: 0.6911
# Epoch 9/10
# 251/251 [==============================] - 24s 95ms/step - loss: 0.6149 - accuracy: 0.6512 - val_loss: 0.5845 - val_accuracy: 0.6876
# Epoch 10/10
# 251/251 [==============================] - 24s 95ms/step - loss: 0.6087 - accuracy: 0.6656 - val_loss: 0.5624 - val_accuracy: 0.7019

# %%
model.evaluate(test_set)
# Out:
# 64/64 [==============================] - 3s 43ms/step - loss: 0.5624 - accuracy: 0.7019
# [0.562394380569458, 0.7019278407096863]
